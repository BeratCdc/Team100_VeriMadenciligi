# %% [markdown]
# # **Kütüphaneleri İçe Aktarma**

# %%
# Gerekli kütüphanelerin içe aktarılması
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, cross_validate, StratifiedKFold, GridSearchCV
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder, FunctionTransformer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn.ensemble import ExtraTreesClassifier
from xgboost import XGBClassifier
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, classification_report, roc_curve

# %%
# Grafik ayarları
sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)

# %%
# Veri setinin okunması
df = pd.read_csv('Hotel Reservations.csv')

# %% [markdown]
# # **Exploratory Data Analysis**

# %%
# Veri seti hakkında genel bilgiler
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36275 entries, 0 to 36274
# Data columns (total 19 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Booking_ID                            36275 non-null  object
#  1   no_of_adults                          36275 non-null  int64
#  2   no_of_children                        36275 non-null  int64
#  3   no_of_weekend_nights                  36275 non-null  int64
#  4   no_of_week_nights                     36275 non-null  int64
#  5   type_of_meal_plan                     36275 non-null  object
#  6   required_car_parking_space            36275 non-null  int64
#  7   room_type_reserved                    36275 non-null  object
#  8   lead_time                             36275 non-null  int64
#  9   arrival_year                          36275 non-null  int64
#  10  arrival_month                         36275 non-null  int64
#  11  arrival_date                          36275 non-null  int64
#  12  market_segment_type                   36275 non-null  object
#  13  repeated_guest                        36275 non-null  int64
#  14  no_of_previous_cancellations          36275 non-null  int64
#  15  no_of_previous_bookings_not_canceled  36275 non-null  int64
#  16  avg_price_per_room                    36275 non-null  float64
#  17  no_of_special_requests                36275 non-null  int64
#  18  booking_status                        36275 non-null  object
# dtypes: float64(1), int64(13), object(5)
# memory usage: 5.3+ MB

# %%
# Sayısal sütunların istatistiksel özeti
df.describe()
# Out:
#        no_of_adults  no_of_children  ...  avg_price_per_room  no_of_special_requests
# count  36275.000000    36275.000000  ...        36275.000000            36275.000000
# mean       1.844962        0.105279  ...          103.423539                0.619655
# std        0.518715        0.402648  ...           35.089424                0.786236
# min        0.000000        0.000000  ...            0.000000                0.000000
# 25%        2.000000        0.000000  ...           80.300000                0.000000
# 50%        2.000000        0.000000  ...           99.450000                0.000000
# 75%        2.000000        0.000000  ...          120.000000                1.000000
# max        4.000000       10.000000  ...          540.000000                5.000000
#
# [8 rows x 14 columns]

# %%
# Veri setinin boyutları
df.shape
# Out:
# (36275, 19)

# %%
# İlk 5 satırın kontrol edilmesi
df.head()
# Out:
#   Booking_ID  no_of_adults  ...  no_of_special_requests  booking_status
# 0   INN00001             2  ...                       0    Not_Canceled
# 1   INN00002             2  ...                       1    Not_Canceled
# 2   INN00003             1  ...                       0        Canceled
# 3   INN00004             2  ...                       0        Canceled
# 4   INN00005             2  ...                       0        Canceled
#
# [5 rows x 19 columns]

# %%
# Son 5 satırın kontrol edilmesi
df.tail()
# Out:
#       Booking_ID  no_of_adults  ...  no_of_special_requests  booking_status
# 36270   INN36271             3  ...                       1    Not_Canceled
# 36271   INN36272             2  ...                       2        Canceled
# 36272   INN36273             2  ...                       2    Not_Canceled
# 36273   INN36274             2  ...                       0        Canceled
# 36274   INN36275             2  ...                       0    Not_Canceled
#
# [5 rows x 19 columns]

# %%
# Eksik değer kontrolü
df.isnull().sum()
# Out:
# Booking_ID                              0
# no_of_adults                            0
# no_of_children                          0
# no_of_weekend_nights                    0
# no_of_week_nights                       0
# type_of_meal_plan                       0
# required_car_parking_space              0
# room_type_reserved                      0
# lead_time                               0
# arrival_year                            0
# arrival_month                           0
# arrival_date                            0
# market_segment_type                     0
# repeated_guest                          0
# no_of_previous_cancellations            0
# no_of_previous_bookings_not_canceled    0
# avg_price_per_room                      0
# no_of_special_requests                  0
# booking_status                          0
# dtype: int64

# %%
# Tüm featurelar
df.columns
# Out:
# Index(['Booking_ID', 'no_of_adults', 'no_of_children', 'no_of_weekend_nights',
#        'no_of_week_nights', 'type_of_meal_plan', 'required_car_parking_space',
#        'room_type_reserved', 'lead_time', 'arrival_year', 'arrival_month',
#        'arrival_date', 'market_segment_type', 'repeated_guest',
#        'no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled',
#        'avg_price_per_room', 'no_of_special_requests', 'booking_status'],
#       dtype='object')

# %%
# Featureların kaç farklı değer içerdiği kontrolü
df.nunique()
# Out:
# Booking_ID                              36275
# no_of_adults                                5
# no_of_children                              6
# no_of_weekend_nights                        8
# no_of_week_nights                          18
# type_of_meal_plan                           4
# required_car_parking_space                  2
# room_type_reserved                          7
# lead_time                                 352
# arrival_year                                2
# arrival_month                              12
# arrival_date                               31
# market_segment_type                         5
# repeated_guest                              2
# no_of_previous_cancellations                9
# no_of_previous_bookings_not_canceled       59
# avg_price_per_room                       3930
# no_of_special_requests                      6
# booking_status                              2
# dtype: int64

# %%
# Tekrar eden satırların (duplicate) kontrolü
duplic = df.duplicated().sum()
print(f"Tekrar eden kayıt sayısı: {duplic}")
# Out:
# Tekrar eden kayıt sayısı: 0

# %%
# Mantıksal hata kontrolü: Hem yetişkin hem çocuk sayısının 0 olduğu kayıtlar mantıksızdır
filtre = (df['no_of_adults'] == 0) & (df['no_of_children'] == 0)
print(f"Hatalı kayıt sayısı: {len(df[filtre])}")
# Out:
# Hatalı kayıt sayısı: 0

# %%
# Hedef değişkenin (Booking Status) dağılım oranları
df['booking_status'].value_counts(normalize=True)
# Out:
# booking_status
# Not_Canceled    0.672364
# Canceled        0.327636
# Name: proportion, dtype: float64

# %%
# Kategorikal veriler
cat_columns = df.select_dtypes(include='object').columns.tolist()
print(cat_columns)
# Out:
# ['Booking_ID', 'type_of_meal_plan', 'room_type_reserved', 'market_segment_type', 'booking_status']

# %%
# Nümerik veriler
num_columns = df.select_dtypes(include='number').columns.tolist()
print(num_columns)
# Out:
# ['no_of_adults', 'no_of_children', 'no_of_weekend_nights', 'no_of_week_nights', 'required_car_parking_space', 'lead_time', 'arrival_year', 'arrival_month', 'arrival_date', 'repeated_guest', 'no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled', 'avg_price_per_room', 'no_of_special_requests']

# %% [markdown]
# # **Veri Görselleştirme**

# %%
# Sayısal değişkenler arasındaki korelasyon haritası
plt.figure(figsize=(12, 10))
sns.heatmap(df[num_columns].corr(), annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Korelasyon Matrisi')
plt.show()

# %%
# Rezervasyon iptal durumunun (Target) görselleştirilmesi
sns.countplot(data=df, x='booking_status')
plt.title("Booking Status Dağılımı")
plt.xlabel("Booking Status")
plt.ylabel("Count")
plt.show()

# %%
# Rezervasyonun yapıldığı tarih ile otele giriş tarihi arasında geçen gün sayısı
df['lead_time'].plot(kind='hist', bins=40)
plt.title("Varış Zamanı Dağılımı")
plt.xlabel("Gün")
plt.show()

# %%
# Aylara göre iptal oranı
monthly_cancel = (df.assign(is_cancel=(df['booking_status']=='Canceled').astype(int))
                    .groupby('arrival_month')['is_cancel'].mean())
monthly_cancel.plot(kind='line', marker='o')
plt.title("Aylara Göre İptal Oranı")
plt.xlabel("Ay")
plt.ylabel("Oran")
plt.show()

# %%
# Fiyata göre iptal oranı
df.boxplot(column='avg_price_per_room', by='booking_status')
plt.suptitle("")
plt.title("Fiyata Göre İptal Durumu")
plt.xlabel("")
plt.ylabel("Oda Başına Ortalama Fiyat")
plt.show()

# %%
# Yemek planı dağılımı
sns.countplot(data=df, x='type_of_meal_plan')
plt.title("Yemek Planı Dağılımı")
plt.xticks(rotation=45)
plt.show()

# %%
# Pazar segmenti dağılımı
sns.countplot(data=df, x='market_segment_type')
plt.xticks(rotation=45)
plt.title("Pazar Segmenti Dağılımı")
plt.show()

# %% [markdown]
# # **Aykırı Değer Analizi**

# %%
# Oda fiyatları outlier
plt.subplot(1, 3, 1)
sns.boxplot(y=df['avg_price_per_room'], color='salmon')
plt.title('Oda Fiyatı Aykırı Değerleri')
# Out:
# Text(0.5, 1.0, 'Oda Fiyatı Aykırı Değerleri')

# %%
# Bekleme süresi outlier
plt.subplot(1, 3, 2)
sns.boxplot(y=df['lead_time'], color='lightblue')
plt.title('Bekleme Süresi (Lead Time) Aykırı Değerleri')
# Out:
# Text(0.5, 1.0, 'Bekleme Süresi (Lead Time) Aykırı Değerleri')

# %%
# Çocuk sayısı outlier
plt.subplot(1, 3, 3)
sns.boxplot(y=df['no_of_children'], color='lightgreen')
plt.title('Çocuk Sayısı Aykırı Değerleri')
# Out:
# Text(0.5, 1.0, 'Çocuk Sayısı Aykırı Değerleri')

# %% [markdown]
# # **Feature Engineering**

# %%
# Fiyatı 0 olan kayıtların temizlenmesi
zero_price = df[df['avg_price_per_room'] == 0]
print("Number of rows with a price of 0:", len(zero_price))
df = df[df['avg_price_per_room'] > 0]
# Out:
# Number of rows with a price of 0: 545

# %%
# Model için gereksiz olan ID sütununun düşürülmesi
df = df.drop('Booking_ID', axis=1)

# %%
# Toplam gece sayısı ve toplam kişi sayısı gibi yeni sütunlar ekleniyor
df['total_nights'] = df['no_of_week_nights'] + df['no_of_weekend_nights']
df['total_people'] = df['no_of_adults'] + df['no_of_children']

# %% [markdown]
# # **Train-Test Split**

# %%
# Hedef değişken ve bağımsız değişken
X = df.drop('booking_status', axis=1)
y = df['booking_status']
# Hedef değişkenin sayısal değere dönüştürülmesi
le = LabelEncoder()
y = le.fit_transform(y)
# Verinin %80 eğitim, %20 test olarak ayrılması(target dengesiz olduğu stratify = y)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 100, stratify = y)

# %% [markdown]
# # **Preprocessor**

# %%
# Eğitim setindeki kategorik ve sayısal sütunların belirlenmesi
categorical_cols = [col for col in X_train.columns if X_train[col].dtype == 'O']
numeric_cols = [col for col in X_train.columns if X_train[col].dtype != 'O']

# %%
# Sayısal veriler için Standartlaştırma (StandardScaler)
# Kategorik veriler için One-Hot Encoding (OneHotEncoder) işlemi
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numeric_cols),
        ('cat', OneHotEncoder(drop='first', handle_unknown='ignore'), categorical_cols)
    ]
)

# %% [markdown]
# # **Gelişmiş Modeller**

# %%
# Xgboost Classifier
xgb_clf = XGBClassifier(eval_metric='logloss', use_label_encoder=False, random_state=42)
# ExtraTrees classifier
et_clf = ExtraTreesClassifier(random_state=42)
# Sparse matrisi dense matrise çevirir
to_dense = FunctionTransformer(lambda x: x.toarray() if hasattr(x, 'toarray') else x, accept_sparse=True)

# %%
pipelines = {
    # Model 1: XGBoost
    '1-XGBoost': Pipeline([
        ('preprocessor', preprocessor),
        ('classifier', xgb_clf)
    ]),
    # Model 2: XGBoost + PCA
    '2-XGBoost + PCA': Pipeline([
        ('preprocessor', preprocessor),
        ('to_dense', to_dense),
        ('pca', PCA()),
        ('classifier', xgb_clf)
    ]),
    # Model 3: XGBoost + SelectKBest
    '3-XGBoost + SelectKBest': Pipeline([
        ('preprocessor', preprocessor),
        ('select', SelectKBest(score_func=f_classif)),
        ('classifier', xgb_clf)
    ]),
    # Model 4: ExtraTrees
    '4-ExtraTrees': Pipeline([
        ('preprocessor', preprocessor),
        ('to_dense', to_dense),
        ('classifier', et_clf)
    ]),
    # Model 5: ExtraTrees + PCA
    '5-ExtraTrees + PCA': Pipeline([
        ('preprocessor', preprocessor),
        ('to_dense', to_dense),
        ('pca', PCA()),
        ('classifier', et_clf)
    ]),
    # Model 6: ExtraTrees + SelectKBest
    '6-ExtraTrees + SelectKBest': Pipeline([
        ('preprocessor', preprocessor),
        ('to_dense', to_dense),
        ('select', SelectKBest(score_func=f_classif)),
        ('classifier', et_clf)
    ])
}

# %% [markdown]
# # **Parameter Tuning**

# %%
param_grids = {
    '1-XGBoost': {
        'classifier__n_estimators': [300, 400, 500],
        'classifier__learning_rate': [0.1],
        'classifier__max_depth': [5, 10, 15]
    },
    '2-XGBoost + PCA': {
        'pca__n_components': [20, 25],
        'classifier__n_estimators': [300, 400, 500],
        'classifier__learning_rate': [0.1],
        'classifier__max_depth': [5, 10, 15]
    },
    '3-XGBoost + SelectKBest': {
        'select__k': [20, 25],
        'classifier__n_estimators': [300, 400, 500],
        'classifier__learning_rate': [0.1],
        'classifier__max_depth': [5, 10, 15]
    },
    '4-ExtraTrees': {
        'classifier__n_estimators': [300, 400, 500],
        'classifier__max_depth': [5, 10, 15]
    },
    '5-ExtraTrees + PCA': {
        'pca__n_components': [20, 25],
        'classifier__n_estimators': [300, 400, 500],
        'classifier__max_depth': [5, 10, 15]
    },
    '6-ExtraTrees + SelectKBest': {
        'select__k': [20, 25],
        'classifier__n_estimators': [300, 400, 500],
        'classifier__max_depth': [5, 10, 15]
    }
}

# %% [markdown]
# # **Cross Validation ile Modelleri Eğitme**

# %%
results = {}
for name, pipeline in pipelines.items():
    print(f"--- {name} Eğitiliyor ---")

    grid = param_grids.get(name)

    if grid:
        # GridSearchCV ile 3 katmanlı doğrulama
        gs = GridSearchCV(pipeline, grid, cv=3, scoring='f1', n_jobs=-1, verbose=1)

        # Modelleri eğit
        gs.fit(X_train, y_train)

        # Sonuçları kaydet
        results[name] = {
            'best_score': gs.best_score_,
            'best_params': gs.best_params_,
            'best_model': gs.best_estimator_
        }
        print(f"En iyi skor: {gs.best_score_:.4f}")
        print(f"En iyi parametreler: {gs.best_params_}\n")
    else:
        print(f"{name} için parametre grid'i bulunamadı!")
# Out:
# --- 1-XGBoost Eğitiliyor ---
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [14:33:53] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# En iyi skor: 0.9214
# En iyi parametreler: {'classifier__learning_rate': 0.1, 'classifier__max_depth': 10, 'classifier__n_estimators': 300}
#
# --- 2-XGBoost + PCA Eğitiliyor ---
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [14:39:40] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# En iyi skor: 0.9104
# En iyi parametreler: {'classifier__learning_rate': 0.1, 'classifier__max_depth': 10, 'classifier__n_estimators': 500, 'pca__n_components': 20}
#
# --- 3-XGBoost + SelectKBest Eğitiliyor ---
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [14:41:07] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# En iyi skor: 0.9169
# En iyi parametreler: {'classifier__learning_rate': 0.1, 'classifier__max_depth': 10, 'classifier__n_estimators': 400, 'select__k': 25}
#
# --- 4-ExtraTrees Eğitiliyor ---
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# En iyi skor: 0.9026
# En iyi parametreler: {'classifier__max_depth': 15, 'classifier__n_estimators': 400}
#
# --- 5-ExtraTrees + PCA Eğitiliyor ---
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# En iyi skor: 0.8967
# En iyi parametreler: {'classifier__max_depth': 15, 'classifier__n_estimators': 500, 'pca__n_components': 25}
#
# --- 6-ExtraTrees + SelectKBest Eğitiliyor ---
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# En iyi skor: 0.9019
# En iyi parametreler: {'classifier__max_depth': 15, 'classifier__n_estimators': 500, 'select__k': 25}

# %% [markdown]
# # **Model Performansları**

# %%
metrics_list = []

# Şekil boyutu ayarla
plt.figure(figsize=(20, 15))

for i, (name, result_data) in enumerate(results.items()):
    best_model = result_data['best_model']

    # Tahmin Yap
    y_pred = best_model.predict(X_test)
    y_prob = best_model.predict_proba(X_test)[:, 1] # ROC-AUC için sınıf olasılığı (pozitif sınıf)

    # Metriklerin Hesaplanması
    acc = accuracy_score(y_test, y_pred)
    prec = precision_score(y_test, y_pred)
    rec = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    auc = roc_auc_score(y_test, y_prob)

    # Listeye ekleme
    metrics_list.append({
        'Model': name,
        'Accuracy': acc,
        'Precision': prec,
        'Recall': rec,
        'F1 Score': f1,
        'ROC AUC': auc
    })

    # Confusion Matrix
    cm = confusion_matrix(y_test, y_pred)

    # Subplot ayarı
    plt.subplot(2, 3, i+1)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title(f"{name}\nF1: {f1:.3f} | AUC: {auc:.3f}")
    plt.ylabel('Gerçek Değer')
    plt.xlabel('Tahmin Edilen')

plt.tight_layout()
plt.show()

# %%
# Tablo Görselleştirilmesi
metrics_df = pd.DataFrame(metrics_list)
metrics_df = metrics_df.round(4)
metrics_df = metrics_df.sort_values(by='F1 Score', ascending=False)

display(metrics_df)
# Out:
#                         Model  Accuracy  Precision  Recall  F1 Score  ROC AUC
# 0                   1-XGBoost    0.9005     0.9117  0.9421    0.9267   0.9573
# 2     3-XGBoost + SelectKBest    0.8992     0.9118  0.9400    0.9257   0.9573
# 1             2-XGBoost + PCA    0.8875     0.8985  0.9373    0.9175   0.9456
# 5  6-ExtraTrees + SelectKBest    0.8686     0.8686  0.9463    0.9058   0.9313
# 3                4-ExtraTrees    0.8620     0.8597  0.9480    0.9017   0.9278
# 4          5-ExtraTrees + PCA    0.8486     0.8327  0.9675    0.8951   0.9289

# %% [markdown]
# # **Sınıf Bazlı Başarım Tablosu**

# %%
table_data = []

# Modeller üzerinde döngü kurarak sonuçları topluyoruz
for name, result_data in results.items():
    best_model = result_data['best_model']

    # Test seti üzerinde tahmin işlemleri
    y_pred = best_model.predict(X_test)

    # ROC-AUC hesaplaması için olasılık değerlerinin alınması
    if hasattr(best_model, "predict_proba"):
        y_prob = best_model.predict_proba(X_test)[:, 1]
        auc_score = roc_auc_score(y_test, y_prob)
    else:
        auc_score = 0

    # Her sınıf için ayrı metrikleri içeren raporu sözlük formatında alıyoruz
    report = classification_report(y_test, y_pred, output_dict=True)

    # NO verilerinin listeye eklenmesi
    table_data.append({
        'Sınıf (Grup)': 'NO',
        'Model': name,
        'F1 Score': report['0']['f1-score'],
        'Precision': report['0']['precision'],
        'Recall': report['0']['recall'],
        'Genel ROC AUC': auc_score
    })

    # YES verilerinin listeye eklenmesi
    table_data.append({
        'Sınıf (Grup)': 'YES',
        'Model': name,
        'F1 Score': report['1']['f1-score'],
        'Precision': report['1']['precision'],
        'Recall': report['1']['recall'],
        'Genel ROC AUC': auc_score
    })

# Verileri DataFrame formatına çeviriyoruz
df_table = pd.DataFrame(table_data)

# Tabloyu önce Sınıf grubuna, sonra Model ismine göre sıralıyoruz.
df_table = df_table.sort_values(by=['Sınıf (Grup)', 'Model'])

# Tabloyu hiyerarşik yapıya dönüştürüyoruz
df_grouped = df_table.set_index(['Sınıf (Grup)', 'Model'])

# Sütunları önem sırasına göre düzenliyoruz
df_grouped = df_grouped[['F1 Score', 'Precision', 'Recall', 'Genel ROC AUC']]

# Tabloyu görselleştirme (Styling)
# F1 skoruna göre yeşil tonlarında renklendirme ve format ayarları
styled_view = df_grouped.style.format("{:.4f}")\
    .background_gradient(cmap='Greens', subset=['F1 Score'])\
    .set_properties(**{'text-align': 'center', 'border-color': 'black'})\
    .set_table_styles([
        {'selector': 'th', 'props': [('font-size', '12px'), ('text-align', 'left'), ('vertical-align', 'middle')]},
        {'selector': 'caption', 'props': [('caption-side', 'top'), ('font-size', '14px'), ('font-weight', 'bold')]}
    ])\
    .set_caption("Sınıf Bazlı Model Performans Karşılaştırması")

display(styled_view)
# Out:
# <style type="text/css">
# #T_787ec th {
#   font-size: 12px;
#   text-align: left;
#   vertical-align: middle;
# }
# #T_787ec caption {
#   caption-side: top;
#   font-size: 14px;
#   font-weight: bold;
# }
# #T_787ec_row0_col0 {
#   background-color: #50b264;
#   color: #f1f1f1;
#   text-align: center;
#   border-color: black;
# }
# #T_787ec_row0_col1, #T_787ec_row0_col2, #T_787ec_row0_col3, #T_787ec_row1_col1, #T_787ec_row1_col2, #T_787ec_row1_col3, #T_787ec_row2_col1, #T_787ec_row2_col2, #T_787ec_row2_col3, #T_787ec_row3_col1, #T_787ec_row3_col2, #T_787ec_row3_col3, #T_787ec_row4_col1, #T_787ec_row4_col2, #T_787ec_row4_col3, #T_787ec_row5_col1, #T_787ec_row5_col2, #T_787ec_row5_col3, #T_787ec_row6_col1, #T_787ec_row6_col2, #T_787ec_row6_col3, #T_787ec_row7_col1, #T_787ec_row7_col2, #T_787ec_row7_col3, #T_787ec_row8_col1, #T_787ec_row8_col2, #T_787ec_row8_col3, #T_787ec_row9_col1, #T_787ec_row9_col2, #T_787ec_row9_col3, #T_787ec_row10_col1, #T_787ec_row10_col2, #T_787ec_row10_col3, #T_787ec_row11_col1, #T_787ec_row11_col2, #T_787ec_row11_col3 {
#   text-align: center;
#   border-color: black;
# }
# #T_787ec_row1_col0 {
#   background-color: #7cc87c;
#   color: #000000;
#   text-align: center;
#   border-color: black;
# }
# #T_787ec_row2_col0 {
#   background-color: #53b466;
#   color: #f1f1f1;
#   text-align: center;
#   border-color: black;
# }
# #T_787ec_row3_col0 {
#   background-color: #d2edcc;
#   color: #000000;
#   text-align: center;
#   border-color: black;
# }
# #T_787ec_row4_col0 {
#   background-color: #f7fcf5;
#   color: #000000;
#   text-align: center;
#   border-color: black;
# }
# #T_787ec_row5_col0 {
#   background-color: #c0e6b9;
#   color: #000000;
#   text-align: center;
#   border-color: black;
# }
# #T_787ec_row6_col0 {
#   background-color: #00441b;
#   color: #f1f1f1;
#   text-align: center;
#   border-color: black;
# }
# #T_787ec_row7_col0 {
#   background-color: #005221;
#   color: #f1f1f1;
#   text-align: center;
#   border-color: black;
# }
# #T_787ec_row8_col0 {
#   background-color: #00451c;
#   color: #f1f1f1;
#   text-align: center;
#   border-color: black;
# }
# #T_787ec_row9_col0 {
#   background-color: #006d2c;
#   color: #f1f1f1;
#   text-align: center;
#   border-color: black;
# }
# #T_787ec_row10_col0 {
#   background-color: #097532;
#   color: #f1f1f1;
#   text-align: center;
#   border-color: black;
# }
# #T_787ec_row11_col0 {
#   background-color: #006529;
#   color: #f1f1f1;
#   text-align: center;
#   border-color: black;
# }
# </style>
# <table id="T_787ec" class="dataframe">
#   <caption>Sınıf Bazlı Model Performans Karşılaştırması</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_787ec_level0_col0" class="col_heading level0 col0" >F1 Score</th>
#       <th id="T_787ec_level0_col1" class="col_heading level0 col1" >Precision</th>
#       <th id="T_787ec_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_787ec_level0_col3" class="col_heading level0 col3" >Genel ROC AUC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sınıf (Grup)</th>
#       <th class="index_name level1" >Model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_787ec_level0_row0" class="row_heading level0 row0" rowspan="6">NO</th>
#       <th id="T_787ec_level1_row0" class="row_heading level1 row0" >1-XGBoost</th>
#       <td id="T_787ec_row0_col0" class="data row0 col0" >0.8452</td>
#       <td id="T_787ec_row0_col1" class="data row0 col1" >0.8755</td>
#       <td id="T_787ec_row0_col2" class="data row0 col2" >0.8169</td>
#       <td id="T_787ec_row0_col3" class="data row0 col3" >0.9573</td>
#     </tr>
#     <tr>
#       <th id="T_787ec_level1_row1" class="row_heading level1 row1" >2-XGBoost + PCA</th>
#       <td id="T_787ec_row1_col0" class="data row1 col0" >0.8231</td>
#       <td id="T_787ec_row1_col1" class="data row1 col1" >0.8622</td>
#       <td id="T_787ec_row1_col2" class="data row1 col2" >0.7875</td>
#       <td id="T_787ec_row1_col3" class="data row1 col3" >0.9456</td>
#     </tr>
#     <tr>
#       <th id="T_787ec_level1_row2" class="row_heading level1 row2" >3-XGBoost + SelectKBest</th>
#       <td id="T_787ec_row2_col0" class="data row2 col0" >0.8436</td>
#       <td id="T_787ec_row2_col1" class="data row2 col1" >0.8716</td>
#       <td id="T_787ec_row2_col2" class="data row2 col2" >0.8173</td>
#       <td id="T_787ec_row2_col3" class="data row2 col3" >0.9573</td>
#     </tr>
#     <tr>
#       <th id="T_787ec_level1_row3" class="row_heading level1 row3" >4-ExtraTrees</th>
#       <td id="T_787ec_row3_col0" class="data row3 col0" >0.7687</td>
#       <td id="T_787ec_row3_col1" class="data row3 col1" >0.8685</td>
#       <td id="T_787ec_row3_col2" class="data row3 col2" >0.6894</td>
#       <td id="T_787ec_row3_col3" class="data row3 col3" >0.9278</td>
#     </tr>
#     <tr>
#       <th id="T_787ec_level1_row4" class="row_heading level1 row4" >5-ExtraTrees + PCA</th>
#       <td id="T_787ec_row4_col0" class="data row4 col0" >0.7281</td>
#       <td id="T_787ec_row4_col1" class="data row4 col1" >0.9034</td>
#       <td id="T_787ec_row4_col2" class="data row4 col2" >0.6098</td>
#       <td id="T_787ec_row4_col3" class="data row4 col3" >0.9289</td>
#     </tr>
#     <tr>
#       <th id="T_787ec_level1_row5" class="row_heading level1 row5" >6-ExtraTrees + SelectKBest</th>
#       <td id="T_787ec_row5_col0" class="data row5 col0" >0.7829</td>
#       <td id="T_787ec_row5_col1" class="data row5 col1" >0.8687</td>
#       <td id="T_787ec_row5_col2" class="data row5 col2" >0.7125</td>
#       <td id="T_787ec_row5_col3" class="data row5 col3" >0.9313</td>
#     </tr>
#     <tr>
#       <th id="T_787ec_level0_row6" class="row_heading level0 row6" rowspan="6">YES</th>
#       <th id="T_787ec_level1_row6" class="row_heading level1 row6" >1-XGBoost</th>
#       <td id="T_787ec_row6_col0" class="data row6 col0" >0.9267</td>
#       <td id="T_787ec_row6_col1" class="data row6 col1" >0.9117</td>
#       <td id="T_787ec_row6_col2" class="data row6 col2" >0.9421</td>
#       <td id="T_787ec_row6_col3" class="data row6 col3" >0.9573</td>
#     </tr>
#     <tr>
#       <th id="T_787ec_level1_row7" class="row_heading level1 row7" >2-XGBoost + PCA</th>
#       <td id="T_787ec_row7_col0" class="data row7 col0" >0.9175</td>
#       <td id="T_787ec_row7_col1" class="data row7 col1" >0.8985</td>
#       <td id="T_787ec_row7_col2" class="data row7 col2" >0.9373</td>
#       <td id="T_787ec_row7_col3" class="data row7 col3" >0.9456</td>
#     </tr>
#     <tr>
#       <th id="T_787ec_level1_row8" class="row_heading level1 row8" >3-XGBoost + SelectKBest</th>
#       <td id="T_787ec_row8_col0" class="data row8 col0" >0.9257</td>
#       <td id="T_787ec_row8_col1" class="data row8 col1" >0.9118</td>
#       <td id="T_787ec_row8_col2" class="data row8 col2" >0.9400</td>
#       <td id="T_787ec_row8_col3" class="data row8 col3" >0.9573</td>
#     </tr>
#     <tr>
#       <th id="T_787ec_level1_row9" class="row_heading level1 row9" >4-ExtraTrees</th>
#       <td id="T_787ec_row9_col0" class="data row9 col0" >0.9017</td>
#       <td id="T_787ec_row9_col1" class="data row9 col1" >0.8597</td>
#       <td id="T_787ec_row9_col2" class="data row9 col2" >0.9480</td>
#       <td id="T_787ec_row9_col3" class="data row9 col3" >0.9278</td>
#     </tr>
#     <tr>
#       <th id="T_787ec_level1_row10" class="row_heading level1 row10" >5-ExtraTrees + PCA</th>
#       <td id="T_787ec_row10_col0" class="data row10 col0" >0.8951</td>
#       <td id="T_787ec_row10_col1" class="data row10 col1" >0.8327</td>
#       <td id="T_787ec_row10_col2" class="data row10 col2" >0.9675</td>
#       <td id="T_787ec_row10_col3" class="data row10 col3" >0.9289</td>
#     </tr>
#     <tr>
#       <th id="T_787ec_level1_row11" class="row_heading level1 row11" >6-ExtraTrees + SelectKBest</th>
#       <td id="T_787ec_row11_col0" class="data row11 col0" >0.9058</td>
#       <td id="T_787ec_row11_col1" class="data row11 col1" >0.8686</td>
#       <td id="T_787ec_row11_col2" class="data row11 col2" >0.9463</td>
#       <td id="T_787ec_row11_col3" class="d

# %% [markdown]
# # **ROC Curve**

# %%
plt.figure(figsize=(12, 10))

# Rastgele tahmin çizgisini ekle
plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='black', label='Rastgele Model (AUC = 0.500)', alpha=0.5)

colors = ['blue', 'orange', 'green', 'red', 'purple', 'brown'] # Her model için farklı renk

for i, (name, result_data) in enumerate(results.items()):
    best_model = result_data['best_model']

    # ROC eğrisi için sınıf olasılıkları
    if hasattr(best_model, "predict_proba"):
        # Sadece pozitif sınıfın (1) olasılığını al
        y_prob = best_model.predict_proba(X_test)[:, 1]

        # FPR, TPR ve Threshold değerlerinin hesaplanması
        fpr, tpr, thresholds = roc_curve(y_test, y_prob)

        # AUC skorunu hesapla
        auc_score = roc_auc_score(y_test, y_prob)

        # Eğriyi çiz
        plt.plot(fpr, tpr, color=colors[i % len(colors)], lw=3,
                 label=f'{name} (AUC = {auc_score:.4f})')
    else:
        print(f"UYARI: {name} modeli olasılık üretemiyor (predict_proba yok), ROC çizilemedi.")

# Grafik Ayarları
plt.xlim([-0.01, 1.0])
plt.ylim([0.0, 1.01])
plt.xlabel('False Positive Rate (Yanlış Pozitif Oranı)', fontsize=14)
plt.ylabel('True Positive Rate (Gerçek Pozitif Oranı / Recall)', fontsize=14)
plt.title('Modellerin ROC Eğrisi Karşılaştırması', fontsize=16, fontweight='bold')
plt.legend(loc="lower right", fontsize=12, frameon=True, shadow=True)
plt.grid(True, linestyle=':', alpha=0.6)

plt.tight_layout()
plt.show()
